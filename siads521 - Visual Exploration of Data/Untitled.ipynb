# %%
# !tar chvfz notebook.tar.gz *
# Out:
# 3d_plotting.ipynb
# Candlestick_Intro.png
# Untitled.ipynb
# annotating_plots.ipynb
# assets/
# assets/nyc_zip_code_tabulation_areas_polygons.geojson
# assets/make_qq_plot.png
# assets/ewcitmeas.txt
# assets/quartet.csv
# assets/tree_maps.ipynb
# assets/stryd.csv
# assets/weighted.jpg
# assets/mads.png
# assets/periodicity.png
# assets/markers.png
# assets/mads_data_post.pkl
# assets/Video_Games_Sales.csv
# assets/tree1.png
# assets/convolution.gif
# assets/VoronoiDiagram.png
# assets/annotating_plots.ipynb
# assets/KS_Example.png
# assets/mapping.ipynb
# assets/Probability Plots-Copy1.ipynb
# assets/Mapping .ipynb
# assets/box_and_violin_plots.ipynb
# assets/subplots.ipynb
# assets/greaterlondon.json
# assets/undersampling.png
# assets/README.txt
# assets/Untitled3.ipynb
# assets/fig_4.png
# assets/out.gif
# assets/Crowd_NYSE.jpg
# assets/subplotting_diagram.png
# assets/2-dimensional .ipynb
# assets/tests.jpg
# assets/privacy.jpeg
# assets/probability_plots.ipynb
# ...
